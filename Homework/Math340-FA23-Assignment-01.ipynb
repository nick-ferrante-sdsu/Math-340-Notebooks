# %% [markdown]
# # Assignment 1
# ## YOUR NAME HERE (LAST, FIRST)
# ## 27 Points Possible
#
# Please complete the following exercises
#
# __READ THIS__
#
# In blocks of code, text following a pound/hashtag symbol # does not execute. It is what we refer to as a comment

# %% [markdown]
# ## Problem
#
#
# ### Exercise 1 - 3 pts each
# Write the solution to the following indefinite integrals using LaTeX.  No credit will be awarded for work turned in in any other format.
#
# Follow the model below.
# $$
# \int \sin(x) dx = -\cos(x) + C
# $$

# %% [markdown]
# ### Exercise 1.1
#
# $$
# \int \sin^{2}(3x) dx
# $$
#
# ### Exercise 1.1 Solution

# %% [markdown]
# ### Exercise 1.2
#
# $$
# \int \frac{dx}{1+4x^2}
# $$
#
# ### Exercise 1.2 Solution

# %% [markdown]
# ### Exercise 1.3
#
# $$
# \int x^{n} dx
# $$
#
# ### Exercise 1.3 Solution

# %% [markdown]
# ### Exercise 2 - 3 pts each
#
# Using the classic result for a geometric series that
#
# $$
# \sum_{n=0}^{\infty}x^{n} = \frac{1}{1-x}, ~ \left|x\right|<1,
# $$
#
# find the following sums.  Use the above statement of the sum of a geometric series as a model.  Again, use LaTeX to write your answers.  No credit will be given otherwise.

# %% [markdown]
# ### Exercise 2.1
# $$
# \sum_{j=0}^{\infty} 3^{j/2}x^{2j}, ~ |x|<\frac{1}{3^{1/4}}.
# $$
# ### Exercise 2.1 Solution

# %% [markdown]
# ### Exercise 2.2
#
# $$
# \sum_{j=0}^{\infty} \sin^{3j}(x), ~ |x|<\frac{\pi}{2}.
# $$
#
# ### Exercise 2.2 Solution

# %% [markdown]
# ### Exercise 2.3
#
# $$
# \sum_{j=1}^{\infty} e^{2jx}, ~ x<0.
# $$
#
# ### Exercise 2.3 Solution

# %% [markdown]
# ### Exercise 3 - 3 points

# %%
# Please note the mechanics for the addition of strings. You do not have to do anything here
msg_1 = "Hello"
msg_2 = ", " # Note that we include the whitespace after the comma
msg_3 = "world"
msg_4 = "!"
str_print = msg_1 + msg_2 + msg_3 + msg_4 # Adding strings appends one string to the next
print(str_print)
# Out:
# Hello, world!

# %% [markdown]
# Using the string methods `.replace` and `.capitalize` ONLY, modify the following string to say
#
# `Do. Or do not. There is no try. -Grand Master Yoda`
#
# Answers which do not implement object methods will not receive credit. Please note punctuation and capitalization of words

# %%
string_variable_1 = "Do, "
string_variable_2 = "or do not."
string_variable_3 = "there ain't not try."
title = "grand Master "
name = "yoDa"

# Combine the modified parts to form the final output
your_answer = "Your answer"
print(your_answer)
# Out:
# Do. Or do not. there is no try. -Grand Master Yoda

# %% [markdown]
# ### Exercise 4 - 3 points each
#
# Create the following functions

# %% [markdown]
# #### Exercise 4.1
#
# Create a function named `my_cube_fn` that takes a single input, computes its cube, and returns the result.

# %%
# Provide your function here. Show some test cases

# %% [markdown]
# #### Exercise 4.2
#
# Create a function named `my_add2` that takes a two inputs, computes their sum, and returns the result.

# %%
# Provide your function here. Show some test cases
